# %% [markdown]
# <a href="https://colab.research.google.com/github/nimajr/MachineLearning2023/blob/main/HW1/Q1/HW1_1_6.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#HW1-Q1.6

# %% [markdown]
# # steps
# 1. eda: exploratory data analysis with pandas profiling
# 2. balance
# 3. using different encoders to handle categorical variables
# 4. normalize using standard scaler
# 5. split train val test
# 6. use KNN, Logistic Regression, SVM
# 7. fit
# 8. predict
# 9. evaluate with accuracy_score, average_precision, roc_auc_score on val and test

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
data = pd.read_csv('/content/BankChurners.csv')

# %%
data.columns
# Out:
# Index(['CLIENTNUM', 'Attrition_Flag', 'Customer_Age', 'Gender',
#        'Dependent_count', 'Education_Level', 'Marital_Status',
#        'Income_Category', 'Card_Category', 'Months_on_book',
#        'Total_Relationship_Count', 'Months_Inactive_12_mon',
#        'Contacts_Count_12_mon', 'Credit_Limit', 'Total_Revolving_Bal',
#        'Avg_Open_To_Buy', 'Total_Amt_Chng_Q4_Q1', 'Total_Trans_Amt',
#        'Total_Trans_Ct', 'Total_Ct_Chng_Q4_Q1', 'Avg_Utilization_Ratio',
#        'Naive_Bayes_Classifier_Attrition_Flag_Card_Category_Contacts_Count_12_mon_Dependent_count_Education_Level_Months_Inactive_12_mon_1',
#        'Naive_Bayes_Classifier_Attrition_Flag_Card_Category_Contacts_Count_12_mon_Dependent_count_Education_Level_Months_Inactive_12_mon_2'],
#       dtype='object')

# %%
train_cols = ['Months_on_book', 'Total_Relationship_Count', 'Months_Inactive_12_mon']
x = data[train_cols]

# %%
import numpy as np
zero_indices = y[y==0].sample(1627).index.values
one_indices = y[y==1].index.values
indices = np.concatenate([zero_indices, one_indices])
data = data.loc[indices]

# %%
data
# Out:
#        CLIENTNUM     Attrition_Flag  Customer_Age Gender  Dependent_count  \
# 7862   711589758  Existing Customer            42      M                5
# 4976   709449333  Existing Customer            49      M                1
# 5827   771450708  Existing Customer            58      F                3
# 4010   759127158  Existing Customer            48      M                3
# 4794   711883833  Existing Customer            50      F                1
# ...          ...                ...           ...    ...              ...
# 10119  716893683  Attrited Customer            55      F                3
# 10123  710638233  Attrited Customer            41      M                2
# 10124  716506083  Attrited Customer            44      F                1
# 10125  717406983  Attrited Customer            30      M                2
# 10126  714337233  Attrited Customer            43      F                2
#
#       Education_Level Marital_Status Income_Category Card_Category  \
# ...

# %%
y = data.Attrition_Flag.map({'Existing Customer': 0, 'Attrited Customer': 1})

# %%
y = data.Attrition_Flag

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=42)
print(x_train.shape)
print(x_test.shape)
print(y_train.shape)
y_test.shape
# Out:
# (8101, 3)
# (2026, 3)
# (8101,)
# (2026,)

# %%
from sklearn.linear_model import LogisticRegression
lr = LogisticRegression()
lr.fit(x_train, y_train)
# Out:
# LogisticRegression()

# %%
lr.score(x_train, y_train)
# Out:
# 0.8376743611899765

# %%
lr.predict(x_test)
# Out:
# array(['Existing Customer', 'Existing Customer', 'Existing Customer', ...,
#        'Existing Customer', 'Existing Customer', 'Existing Customer'],
#       dtype=object)

# %%
y.value_counts()
# Out:
# Attrition_Flag
# Existing Customer    8500
# Attrited Customer    1627
# Name: count, dtype: int64

# %%
8500 / len(y)
# Out:
# 0.8393403772094401

# %%
from sklearn.metrics import accuracy_score
accuracy_score(y_train, lr.predict(x_train))
# Out:
# 0.8376743611899765

# %%
# prompt: use knn and train

from sklearn.neighbors import KNeighborsClassifier

knn = KNeighborsClassifier(n_neighbors=5) # You can adjust the number of neighbors
knn.fit(x_train, y_train)
knn_predictions = knn.predict(x_test)

accuracy_knn = accuracy_score(y_test, knn_predictions)
print(f"KNN Accuracy: {accuracy_knn}")
# Out:
# KNN Accuracy: 0.8139190523198421

# %%
from sklearn.metrics import roc_auc_score, average_precision_score
average_precision = roc_auc_score(y_test, knn_predictions)
print(f"Average Precision: {average_precision}")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-21-4ef2fea4e83f> in <cell line: 2>()
#       1 from sklearn.metrics import roc_auc_score, average_precision_score
# ----> 2 average_precision = roc_auc_score(y_test, knn_predictions)
#       3 print(f"Average Precision: {average_precision}")
#
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/_param_validation.py in wrapper(*args, **kwargs)
#     211                     )
#     212                 ):
# --> 213                     return func(*args, **kwargs)
#     214             except InvalidParameterError as e:
#     215                 # When the function is just a wrapper around an estimator, we allow
#
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_ranking.py in roc_auc_score(y_true, y_score, average, sample_weight, max_fpr, multi_class, labels)
# ...
